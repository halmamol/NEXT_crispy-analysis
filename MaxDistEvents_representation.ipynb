# %%
import os
import sys

import numpy  as np
import tables as tb
import pandas as pd
import matplotlib
import math

#the line below makes the plot as a pop-up, that can be saved
#matplotlib.use('TkAgg')

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as clrs

import matplotlib.cm as cm
from matplotlib.colors import Normalize

from IC.invisible_cities.evm.event_model        import Cluster, Hit
from IC.invisible_cities.types.ic_types         import xy
from IC.invisible_cities.reco.paolina_functions import voxelize_hits

from IC.invisible_cities.core.exceptions import NoHits

# %%
import functions.histo_functions as myhf
import functions.efficiency_functions as myef
import functions.recovstrue as myrvt

# %%
npz_path = '/Users/halmamol/NEXT/NBarrays/'
npz_filename_FS = 'tracklimits_FULLSIM.npz'
npz_filename_FS_tb = 'tracklimits_FULLSIM_tb.npz'
npz_filename_DS = 'tracklimits_DETSIM.npz'
npz_filename_DS_tb = 'tracklimits_DETSIM_tb.npz'

# %%
d_FS = np.load(npz_path+npz_filename_FS)
d_FS_tb = np.load(npz_path+npz_filename_FS_tb)

d_DS = np.load(npz_path+npz_filename_DS)
d_DS_tb = np.load(npz_path+npz_filename_DS_tb)

track_0nubb_zmin_FS = d_FS['track_0nubb_zmin']
track_0nubb_zmax_FS = d_FS['track_0nubb_zmax']
track_0nubb_rmax_FS = d_FS['track_0nubb_rmax']

track_selectron_zmin_FS = d_FS['track_selectron_zmin']
track_selectron_zmax_FS = d_FS['track_selectron_zmax']
track_selectron_rmax_FS = d_FS['track_selectron_rmax']

track_0nubb_zmin_FS_tb = d_FS_tb['track_0nubb_zmin']
track_0nubb_zmax_FS_tb = d_FS_tb['track_0nubb_zmax']
track_0nubb_rmax_FS_tb = d_FS_tb['track_0nubb_rmax']

track_selectron_zmin_FS_tb = d_FS_tb['track_selectron_zmin']
track_selectron_zmax_FS_tb = d_FS_tb['track_selectron_zmax']
track_selectron_rmax_FS_tb = d_FS_tb['track_selectron_rmax']

track_0nubb_zmin_DS = d_DS['track_0nubb_zmin']
track_0nubb_zmax_DS = d_DS['track_0nubb_zmax']
track_0nubb_rmax_DS = d_DS['track_0nubb_rmax']

track_selectron_zmin_DS = d_DS['track_selectron_zmin']
track_selectron_zmax_DS = d_DS['track_selectron_zmax']
track_selectron_rmax_DS = d_DS['track_selectron_rmax']

track_0nubb_zmin_DS_tb = d_DS_tb['track_0nubb_zmin']
track_0nubb_zmax_DS_tb = d_DS_tb['track_0nubb_zmax']
track_0nubb_rmax_DS_tb = d_DS_tb['track_0nubb_rmax']

track_selectron_zmin_DS_tb = d_DS_tb['track_selectron_zmin']
track_selectron_zmax_DS_tb = d_DS_tb['track_selectron_zmax']
track_selectron_rmax_DS_tb = d_DS_tb['track_selectron_rmax']

# %%
track_0nubb_zmin_FS_tb
# Out:
# array([310.20525   ,  85.2245    , 120.79978125, ..., 467.3891875 ,
#        840.2183125 , 842.11825   ])

# %% [markdown]
# ### FULLSIM

# %%
plt.hist(track_0nubb_zmin_FS, bins = 50, range = (0, 1400), density=True, color='blue', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_zmin_FS_tb, bins = 50, range = (0, 1400), density=True, color='blue', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb FULLSIM - zmin')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_zmax_FS, bins = 50, range = (0, 1400), density=True, color='green', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_zmax_FS_tb, bins = 50, range = (0, 1400), density=True, color='green', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb FULLSIM - zmax')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_rmax_FS, bins = 50, range = (0, 650), density=True, color='red', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_rmax_FS_tb, bins = 50, range = (0, 650), density=True, color='red', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb FULLSIM - rmax')
plt.legend(loc=2);
plt.show()

# %% [markdown]
# ### DETSIM

# %%
plt.hist(track_0nubb_zmin_DS, bins = 50, range = (0, 1400), density=True, color='blue', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_zmin_DS_tb, bins = 50, range = (0, 1400), density=True, color='blue', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb DETSIM - zmin')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_zmax_DS, bins = 50, range = (0, 1400), density=True, color='green', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_zmax_DS_tb, bins = 50, range = (0, 1400), density=True, color='green', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb DETSIM - zmax')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_rmax_DS, bins = 50, range = (0, 650), density=True, color='red', histtype='step', label = 'B-C + itol 0.001')
plt.hist(track_0nubb_rmax_DS_tb, bins = 50, range = (0, 650), density=True, color='red', histtype='step', label = 'B-N + itol 0.1', linestyle='dashed')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb DETSIM - rmax')
plt.legend(loc=2);
plt.show()

# %% [markdown]
# ## FULLSIM VS DETSIM

# %%
plt.hist(track_0nubb_zmin_FS, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_zmin_DS, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-C + itol 0.001 - zmin')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_zmax_FS, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_zmax_DS, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-C + itol 0.001 - zmax')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_rmax_FS, bins = 50, range = (0, 650), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_rmax_DS, bins = 50, range = (0, 650), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-C + itol 0.001 - rmax')
plt.legend(loc=2);
plt.show()

# %%
plt.hist(track_0nubb_zmin_FS_tb, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_zmin_DS_tb, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-N + itol 0.1 - zmin')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_zmax_FS_tb, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_zmax_DS_tb, bins = 50, range = (0, 1400), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-N + itol 0.1 - zmin')
plt.legend(loc=1);
plt.show()

# %%
plt.hist(track_0nubb_rmax_FS_tb, bins = 50, range = (0, 650), density=True, alpha=0.6, color='orange', label = 'FULLSIM')
plt.hist(track_0nubb_rmax_DS_tb, bins = 50, range = (0, 650), density=True, alpha=0.6, color='green', label = 'DETSIM')

plt.xlabel('position (mm)')
plt.ylabel('events (a.u.)')
plt.title('0nubb B-N + itol 0.1 - zmin')
plt.legend(loc=2);
plt.show()
